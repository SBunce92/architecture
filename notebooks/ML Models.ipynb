# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
archi = pd.read_csv('architecture_text_only.csv')

# %%
archi[archi.building_main_style == ('neoclassical' and 'modern')]
# Out:
#                             building_architect   building_city  \
# 2                                          NaN           tampa
# 4                                         zofa          zwolle
# 6                                      mecanoo       rotterdam
# 10                             rkw-architektur          gdansk
# 12                                         NaN   weil_am_rhein
# 19                           natoma-architects   san_francisco
# 22                                         NaN          dallas
# 29                                         NaN         hamburg
# 30                              hamonic-masson   fontainebleau
# 32                                         NaN           paris
# 35                                         NaN           milan
# 41                                         NaN        florence
# 43                            herzog-de-meuron        bordeaux
# 44                                         NaN       arantzazu
# ...
