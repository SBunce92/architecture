# %%
from bs4 import BeautifulSoup
import re
from PIL import Image
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join
from unidecode import unidecode

# %%
def building_dataframe(htmlfile):
    '''This function extracts all of the relevant data from each html file iteratively.
    It constructs a pandas table for each building, with its jpg files as the row indexes'''
    
    file1 = open(htmlfile, "r")
    soup = BeautifulSoup(file1, 'html.parser')
        
    jpglist =[str((link.get('href')).split('/')[-1]) for link in soup.find_all('a') if ("flickr" and "jpg") in (link.get('href'))]
    # This finds filenames for all of the associated jpgs
    if jpglist == []:
        return 
    
    architect_val = [(link.get('href')) for link in soup.find_all('a') if ("firms/") in (link.get('href'))][1].split('/')[-1]
    date_val = str(soup.find('table', id='building_info_tbl').find('td', text='Date').findNext('td'))
    style_val = [(link.get('href')) for link in soup.find_all('a') if ("styles/") in (link.get('href'))][1].split('/')[-1]
    type_val = [(link.get('href')) for link in soup.find_all('a') if ("types/") in (link.get('href'))][1].split('/')[-1]
    buildingname_val = htmlfile.split('/')[-1].split('.')[0]
    latitude_val = soup.find(string=re.compile("Latitude"))
    longitude_val = soup.find(string=re.compile("Longitude"))
    city_val = [(link.get('href')) for link in soup.find_all('a') if ("locations/city") in (link.get('href'))][0].split('/')[-1].split('-')[0]
    country_val = [(link.get('href')) for link in soup.find_all('a') if ("locations/country") in (link.get('href'))][0].split('/')[-1]
    tag_vals = list(set([(link.get('href')).split('/')[-1] for link in soup.find_all('a') if ("/tags/" and "/name/") in (link.get('href'))]))
    # This generates links to all of the tags for each building

    columns = ['jpg_name','building_name', 'building_date', 'building_city', 'building_country', 'building_latitude', 'building_longitude', 'building_architect', 'building_style', 'building_type']
    building_df = pd.DataFrame(columns=columns)
    building_df.jpg_name = jpglist

    tag_df = pd.DataFrame(1, index=np.arange(len(building_df)), columns=['feature_' + a for a in tag_vals])
    building_df = pd.concat([building_df, tag_df], axis=1)
    
    building_df.building_architect = architect_val
    building_df.building_country = country_val
    building_df.building_city = city_val
    building_df.building_date = date_val.strip('<td valign="top">').strip('</')
    building_df.building_name = buildingname_val
    building_df.building_latitude = latitude_val
    building_df.building_longitude = longitude_val
    building_df.building_style = style_val
    building_df.building_type = type_val
    building_df = building_df[pd.notnull(building_df.jpg_name)].set_index('jpg_name')
    return building_df

def lat_clean(inputstr):
    return float(inputstr.strip('\n').strip().strip('\tLatitude(').strip('),'))

def lon_clean(inputstr):
    return float(inputstr.strip('\n').strip().strip('\tLongitude(').strip('),'))

def BC_to_minus(date_string):
    ''' This function checks for the presence of 'BC' in a date, and converts it to a minus sign'''
    minus_string = ''
    if 'BC' in str(date_string):
        minus_string = '-'  
    date_draft = minus_string + str(date_string)
    return date_draft
    
def date_clean(date_string):
    ''' This function checks for range dates (ie. 200BC - 800AD) and converts them to ints (-200 - 800)
    and then averages them. If the date is not a compound date, then it checks for BC, and returns a single
    number ie. -800 or 1200.'''
    if '-' in date_string:
        date_string = (int(BC_to_minus(date_string.split('-')[0]).strip(' BC').strip(' AD')) +  \
        int(BC_to_minus(date_string.split('-')[1]).strip(' BC').strip(' AD')))/2
    date_string = str(BC_to_minus(date_string)).strip(' BC').strip(' AD').replace(" ", "")
    return date_string

def style_replace(textstr):
    '''Replaces the names of styles to avoid searching for special characters'''
    if 'covenesc' in textstr:
        textstr = 'brancovenesc'
    elif 'mud' in textstr:
        textstr = 'mudejar'
    else:
        textstr = textstr
    return textstr

def letter_replace(string):  
    '''Replaces certain non ascii characters with their ascii approximations'''
    replace_dict = {'\xc3\xa3':'a', '\xc3\xb5':'o', '\xc5\x8d':'o', '\xc3\x9f':'ss', 
                '\xc3\xad':'i', '\xc3\xa1':'a', '\xc3\xa8':'e', '\xc4\xb1':'i', '\xda':'u', '\xed':'i',
                '\xc5':'a', '\xe9':'e', '\xe2':'a'}
    for k in replace_dict:  
        string = string.replace(k,replace_dict[k])  
    return string

def tidy_main_table(raw_concat_input):
    ''' After the whole database of buildings has been assembled into a single pandas table, this function
    cleans up the values for some of the columns'''
    architecture_csv = raw_concat_input

    #Tidy Lon and Lat
    architecture_csv.building_latitude = architecture_csv.building_latitude.apply(lat_clean)
    architecture_csv.building_longitude = architecture_csv.building_longitude.apply(lon_clean)
    architecture_csv = architecture_csv.dropna(subset = ['building_latitude', 'building_longitude'])

    #Drop duplicate images and drop rows which don't have associated photos in the file
    architecture_csv = architecture_csv.reset_index().drop_duplicates(subset='jpg_name', keep='last').set_index('jpg_name')
    architecture_csv = architecture_csv.drop(list(set(architecture_csv.index) - set(photo_names)))

    #Sorts out subcategories for building types and styles (turns 2 cols into 4)
    styles_db = pd.DataFrame(architecture_csv.building_style.str.split('---',1).tolist(), columns = ['building_main_style','building_sub_style'], index = architecture_csv.index)
    types_db = pd.DataFrame(architecture_csv.building_type.str.split('---',1).tolist(), columns = ['building_main_type','building_sub_type'], index = architecture_csv.index)
    architecture_csv = pd.concat([architecture_csv, styles_db, types_db], axis=1).drop(['building_type', 'building_style'], 1)

    #Replace feature_ column NAs with 0s
    feature_columns = [a for a in list(architecture_csv.columns) if a.startswith('feature_')]
    architecture_csv[feature_columns] = architecture_csv[feature_columns].fillna(0)

    #Extract dates and switch them to numeric
    architecture_csv.building_date = pd.to_numeric(architecture_csv.building_date.apply(date_clean))
    
    #Remove special accented characters from column names and building_name and building_city
    architecture_csv.columns = [unidecode(text) for text in list(architecture_csv.columns)]
    architecture_csv.building_name = architecture_csv.building_name.apply(letter_replace).apply(unidecode)
    architecture_csv.building_main_style = architecture_csv.building_main_style.apply(style_replace)
    
    return architecture_csv

# %%
#Directories and file lists
photo_dir = '/home/sam/Documents/Architecture/photos/'
html_dir = '/home/sam/Documents/Architecture/buildings/'
html_files = [join(html_dir, f) for f in listdir(html_dir) if isfile(join(html_dir, f))]
photo_files = [join(photo_dir, f) for f in listdir(photo_dir) if isfile(join(photo_dir, f))]
photo_names = [f for f in listdir(photo_dir) if isfile(join(photo_dir, f))]
len(html_files)
# Out:
# 7657

# %%
# Assemble the databases for individual html files, and the concat them into one main db, then tidy
architecture_csv = tidy_main_table(pd.concat([(building_dataframe(i)) for i in html_files]))

# %%
architecture_csv
# Out:
#                              building_architect building_city  \
# jpg_name
# 3689713225_537b89d9b4.jpg                                bari
# 2895586914_fe794fc4ca.jpg                                bari
# 3690519530_e1b73f4f55.jpg                                bari
# 4368203413_92c3399cda_z.jpg                            madrid
# 3625883327_c23d151149_z.jpg                            madrid
# 16626841870_66ef40bbb4_b.jpg                           madrid
# 4385858902_d6e9e7c654.jpg                               tampa
# 4981284997_04d7c38fea.jpg                               tampa
# 4981285055_3e4a18f8c7.jpg                               tampa
# 1418888097_715cf79a6b.jpg                               nimes
# 5512901641_e3ce133848.jpg                               nimes
# 378526474_e96daf44a3.jpg                                nimes
# 5027110955_5f6df0b54d.jpg                  zofa        zwolle
# 5027115885_2c3e3d0d63.jpg                  zofa        zwolle
# 3558094115_ef492ef884.jpg                  zofa        zwolle
# 3853535763_a871815d68.jpg                              la_paz
# 3191802718_0b625b5473.jpg                              la_paz
# 3853534467_1c8b56a304.jpg                              la_paz
# 6779125019_c560ea8d2c.jpg               mecanoo     rotterdam
# 1404753880_f1b9b6046c.jpg               mecanoo     rotterdam
# 5751067125_fe1f154b09.jpg               mecanoo     rotterdam
# 66919505_39e17583d6.jpg                             cleveland
# 4465317510_3255b4539c.jpg                           cleveland
# 5030418712_44fd2dce38.jpg                             messina
# 3364699979_4f16359b70.jpg                             messina
# 6584963027_ef55825ecf_b.jpg                       miami_beach
# 8209621242_70b6931e71_b.jpg                       miami_beach
# 5425674028_cdff31c27f_b.jpg                       miami_beach
# 6014739523_ecef84bee5.jpg       rkw-architektur        gdansk
# 6015248296_b7e893e74e.jpg       rkw-architektur        gdansk
# ...                                         ...           ...
# 2521458754_463b5e3f29.jpg         nikken-sekkei         tokyo
# 3968504263_e03b5b162c.jpg                                tuba
# 4903978088_5c69e05130.jpg                                tuba
# 4903389675_d44822b49c.jpg                                tuba
# 2373204758_fb40abda43_o.jpg                           tianjin
# 2620391981_0ba61118f6_z.jpg                           tianjin
# 3321920891_57f5359ea7_b.jpg                           tianjin
# 5210350350_223a960a20.jpg                          higashiomi
# 5209755927_eeab13f204.jpg                          higashiomi
# 5210305092_fa300b7895.jpg                          higashiomi
# 8669942886_e328513a71_b.jpg     adns-architekti        prague
# 2528949652_d431f64e0c.jpg      valode-et-pistre         paris
# 3389649775_c2c6682018.jpg      valode-et-pistre         paris
# 2823335798_afb43b8dbc.jpg      valode-et-pistre         paris
# 3482362202_deeb923920_b.jpg                          la_jolla
# 6814677809_a500c1168e_b.jpg                          la_jolla
# 4533888124_347b9b2953_b.jpg                          la_jolla
# 5950681881_b90166cb44.jpg                          cuernavaca
# 25380616_00614f85d4.jpg                            cuernavaca
# 3461463230_bd8bc03914.jpg                          cuernavaca
# 4152967191_d3a647e9d0.jpg                           bucharest
# 5367755404_46d3222e5f.jpg                           bucharest
# 4340961465_849a4047cc.jpg                           bucharest
# 3967379808_4526c9c59b.jpg                                pisa
# 2988311084_558330f83d.jpg                                pisa
# 2844827222_711aa34f1b.jpg                                pisa
# 6373349711_f50e22bdaf.jpg        voa-associates   terre_haute
# 6967159233_e70f3f0b05.jpg       ksg-architekten      freiburg
# 6821038704_c1a202e644.jpg       ksg-architekten      freiburg
# 7354312436_b251469d3e.jpg       ksg-architekten      freiburg
#
#                              building_country  building_date  \
# jpg_name
# 3689713225_537b89d9b4.jpg               italy        -1200.0
# 2895586914_fe794fc4ca.jpg               italy        -1200.0
# 3690519530_e1b73f4f55.jpg               italy        -1200.0
# 4368203413_92c3399cda_z.jpg             spain         1926.0
# 3625883327_c23d151149_z.jpg             spain         1926.0
# 16626841870_66ef40bbb4_b.jpg            spain         1926.0
# 4385858902_d6e9e7c654.jpg       united_states         1968.0
# 4981284997_04d7c38fea.jpg       united_states         1968.0
# 4981285055_3e4a18f8c7.jpg       united_states         1968.0
# 1418888097_715cf79a6b.jpg              france           10.0
# 5512901641_e3ce133848.jpg              france           10.0
# 378526474_e96daf44a3.jpg               france           10.0
# 5027110955_5f6df0b54d.jpg     the_netherlands         2005.0
# 5027115885_2c3e3d0d63.jpg     the_netherlands         2005.0
# 3558094115_ef492ef884.jpg     the_netherlands         2005.0
# 3853535763_a871815d68.jpg             bolivia         1835.0
# 3191802718_0b625b5473.jpg             bolivia         1835.0
# 3853534467_1c8b56a304.jpg             bolivia         1835.0
# 6779125019_c560ea8d2c.jpg     the_netherlands         2005.0
# 1404753880_f1b9b6046c.jpg     the_netherlands         2005.0
# 5751067125_fe1f154b09.jpg     the_netherlands         2005.0
# 66919505_39e17583d6.jpg         united_states         1991.0
# 4465317510_3255b4539c.jpg       united_states         1991.0
# 5030418712_44fd2dce38.jpg               italy         1200.0
# 3364699979_4f16359b70.jpg               italy         1200.0
# 6584963027_ef55825ecf_b.jpg     united_states         1927.0
# 8209621242_70b6931e71_b.jpg     united_states         1927.0
# 5425674028_cdff31c27f_b.jpg     united_states         1927.0
# 6014739523_ecef84bee5.jpg              poland         2011.0
# 6015248296_b7e893e74e.jpg              poland         2011.0
# ...                                       ...            ...
# 2521458754_463b5e3f29.jpg               japan         2008.0
# 3968504263_e03b5b162c.jpg              jordan          743.0
# 4903978088_5c69e05130.jpg              jordan          743.0
# 4903389675_d44822b49c.jpg              jordan          743.0
# 2373204758_fb40abda43_o.jpg             china         2006.0
# 2620391981_0ba61118f6_z.jpg             china         2006.0
# 3321920891_57f5359ea7_b.jpg             china         2006.0
# 5210350350_223a960a20.jpg               japan         1000.0
# 5209755927_eeab13f204.jpg               japan         1000.0
# 5210305092_fa300b7895.jpg               japan         1000.0
# 8669942886_e328513a71_b.jpg    czech_republic         2005.0
# 2528949652_d431f64e0c.jpg              france         2008.0
# 3389649775_c2c6682018.jpg              france         2008.0
# 2823335798_afb43b8dbc.jpg              france         2008.0
# 3482362202_deeb923920_b.jpg     united_states         1970.0
# 6814677809_a500c1168e_b.jpg     united_states         1970.0
# 4533888124_347b9b2953_b.jpg     united_states         1970.0
# 5950681881_b90166cb44.jpg              mexico         1300.0
# 25380616_00614f85d4.jpg                mexico         1300.0
# 3461463230_bd8bc03914.jpg              mexico         1300.0
# 4152967191_d3a647e9d0.jpg             romania         2007.0
# 5367755404_46d3222e5f.jpg             romania         2007.0
# 4340961465_849a4047cc.jpg             romania         2007.0
# 3967379808_4526c9c59b.jpg               italy         1278.0
# 2988311084_558330f83d.jpg               italy         1278.0
# 2844827222_711aa34f1b.jpg               italy         1278.0
# 6373349711_f50e22bdaf.jpg       united_states         2005.0
# 6967159233_e70f3f0b05.jpg             germany         2004.0
# 6821038704_c1a202e644.jpg             germany         2004.0
# 7354312436_b251469d3e.jpg             germany         2004.0
#
#                               building_latitude  building_longitude  \
# jpg_name
# 3689713225_537b89d9b4.jpg             41.194099           16.487419
# 2895586914_fe794fc4ca.jpg             41.194099           16.487419
# 3690519530_e1b73f4f55.jpg             41.194099           16.487419
# 4368203413_92c3399cda_z.jpg           40.442684           -3.699627
# 3625883327_c23d151149_z.jpg           40.442684           -3.699627
# 16626841870_66ef40bbb4_b.jpg          40.442684           -3.699627
# 4385858902_d6e9e7c654.jpg             27.962130          -82.504959
# 4981284997_04d7c38fea.jpg             27.962130          -82.504959
# 4981285055_3e4a18f8c7.jpg             27.962130          -82.504959
# 1418888097_715cf79a6b.jpg             43.838188            4.356106
# 5512901641_e3ce133848.jpg             43.838188            4.356106
# 378526474_e96daf44a3.jpg              43.838188            4.356106
# 5027110955_5f6df0b54d.jpg             52.539909            6.078663
# 5027115885_2c3e3d0d63.jpg             52.539909            6.078663
# 3558094115_ef492ef884.jpg             52.539909            6.078663
# 3853535763_a871815d68.jpg            -16.496149          -68.134079
# 3191802718_0b625b5473.jpg            -16.496149          -68.134079
# 3853534467_1c8b56a304.jpg            -16.496149          -68.134079
# 6779125019_c560ea8d2c.jpg             51.903999            4.485538
# 1404753880_f1b9b6046c.jpg             51.903999            4.485538
# 5751067125_fe1f154b09.jpg             51.903999            4.485538
# 66919505_39e17583d6.jpg               41.500999          -81.693817
# 4465317510_3255b4539c.jpg             41.500999          -81.693817
# 5030418712_44fd2dce38.jpg             38.191238           15.556250
# 3364699979_4f16359b70.jpg             38.191238           15.556250
# 6584963027_ef55825ecf_b.jpg           25.782623          -80.132637
# 8209621242_70b6931e71_b.jpg           25.782623          -80.132637
# 5425674028_cdff31c27f_b.jpg           25.782623          -80.132637
# 6014739523_ecef84bee5.jpg             54.390270           18.640270
# 6015248296_b7e893e74e.jpg             54.390270           18.640270
# ...                                         ...                 ...
# 2521458754_463b5e3f29.jpg             35.629650          139.779205
# 3968504263_e03b5b162c.jpg             31.326111           36.570862
# 4903978088_5c69e05130.jpg             31.326111           36.570862
# 4903389675_d44822b49c.jpg             31.326111           36.570862
# 2373204758_fb40abda43_o.jpg           39.084938          117.209099
# 2620391981_0ba61118f6_z.jpg           39.084938          117.209099
# 3321920891_57f5359ea7_b.jpg           39.084938          117.209099
# 5210350350_223a960a20.jpg             35.161289          136.283096
# 5209755927_eeab13f204.jpg             35.161289          136.283096
# 5210305092_fa300b7895.jpg             35.161289          136.283096
# 8669942886_e328513a71_b.jpg           50.048790           14.429163
# 2528949652_d431f64e0c.jpg             48.895351            2.239899
# 3389649775_c2c6682018.jpg             48.895351            2.239899
# 2823335798_afb43b8dbc.jpg             48.895351            2.239899
# 3482362202_deeb923920_b.jpg           32.875629         -117.240250
# 6814677809_a500c1168e_b.jpg           32.875629         -117.240250
# 4533888124_347b9b2953_b.jpg           32.875629         -117.240250
# 5950681881_b90166cb44.jpg             18.930380          -99.222023
# 25380616_00614f85d4.jpg               18.930380          -99.222023
# 3461463230_bd8bc03914.jpg             18.930380          -99.222023
# 4152967191_d3a647e9d0.jpg             44.439449           26.098579
# 5367755404_46d3222e5f.jpg             44.439449           26.098579
# 4340961465_849a4047cc.jpg             44.439449           26.098579
# 3967379808_4526c9c59b.jpg             43.723949           10.395650
# 2988311084_558330f83d.jpg             43.723949           10.395650
# 2844827222_711aa34f1b.jpg             43.723949           10.395650
# 6373349711_f50e22bdaf.jpg             39.482552          -87.329323
# 6967159233_e70f3f0b05.jpg             47.999828            7.791150
# 6821038704_c1a202e644.jpg             47.999828            7.791150
# 7354312436_b251469d3e.jpg             47.999828            7.791150
#
#                                                    building_name  \
# jpg_name
# 3689713225_537b89d9b4.jpg                    dolmen-of-bisceglie
# 2895586914_fe794fc4ca.jpg                    dolmen-of-bisceglie
# 3690519530_e1b73f4f55.jpg                    dolmen-of-bisceglie
# 4368203413_92c3399cda_z.jpg               moseo-geominero-madrid
# 3625883327_c23d151149_z.jpg               moseo-geominero-madrid
# 16626841870_66ef40bbb4_b.jpg              moseo-geominero-madrid
# 4385858902_d6e9e7c654.jpg                     futuro-house-tampa
# 4981284997_04d7c38fea.jpg                     futuro-house-tampa
# 4981285055_3e4a18f8c7.jpg                     futuro-house-tampa
# 1418888097_715cf79a6b.jpg                          maison-carree
# 5512901641_e3ce133848.jpg                          maison-carree
# 378526474_e96daf44a3.jpg                           maison-carree
# 5027110955_5f6df0b54d.jpg                        zrzv-club-house
# 5027115885_2c3e3d0d63.jpg                        zrzv-club-house
# 3558094115_ef492ef884.jpg                        zrzv-club-house
# 3853535763_a871815d68.jpg       metropolitan-cathedral-of-la-paz
# 3191802718_0b625b5473.jpg       metropolitan-cathedral-of-la-paz
# 3853534467_1c8b56a304.jpg       metropolitan-cathedral-of-la-paz
# 6779125019_c560ea8d2c.jpg                            monte-video
# 1404753880_f1b9b6046c.jpg                            monte-video
# 5751067125_fe1f154b09.jpg                            monte-video
# 66919505_39e17583d6.jpg                                key-tower
# 4465317510_3255b4539c.jpg                              key-tower
# 5030418712_44fd2dce38.jpg                catalani-church-messina
# 3364699979_4f16359b70.jpg                catalani-church-messina
# 6584963027_ef55825ecf_b.jpg                  miami-old-city-hall
# 8209621242_70b6931e71_b.jpg                  miami-old-city-hall
# 5425674028_cdff31c27f_b.jpg                  miami-old-city-hall
# 6014739523_ecef84bee5.jpg                       pge-arena-gdansk
# 6015248296_b7e893e74e.jpg                       pge-arena-gdansk
# ...                                                          ...
# 2521458754_463b5e3f29.jpg                    nomura-headquarters
# 3968504263_e03b5b162c.jpg                              qasr-tuba
# 4903978088_5c69e05130.jpg                              qasr-tuba
# 4903389675_d44822b49c.jpg                              qasr-tuba
# 2373204758_fb40abda43_o.jpg                       tianjin-museum
# 2620391981_0ba61118f6_z.jpg                       tianjin-museum
# 3321920891_57f5359ea7_b.jpg                       tianjin-museum
# 5210350350_223a960a20.jpg                     kongorin-ji-temple
# 5209755927_eeab13f204.jpg                     kongorin-ji-temple
# 5210305092_fa300b7895.jpg                     kongorin-ji-temple
# 8669942886_e328513a71_b.jpg                 kavci-hory-residence
# 2528949652_d431f64e0c.jpg                                tour-t1
# 3389649775_c2c6682018.jpg                                tour-t1
# 2823335798_afb43b8dbc.jpg                                tour-t1
# 3482362202_deeb923920_b.jpg                   the-breezeway-ucsd
# 6814677809_a500c1168e_b.jpg                   the-breezeway-ucsd
# 4533888124_347b9b2953_b.jpg                   the-breezeway-ucsd
# 5950681881_b90166cb44.jpg                    teopanzolco-pyramid
# 25380616_00614f85d4.jpg                      teopanzolco-pyramid
# 3461463230_bd8bc03914.jpg                    teopanzolco-pyramid
# 4152967191_d3a647e9d0.jpg     romanian-architects-association-hq
# 5367755404_46d3222e5f.jpg     romanian-architects-association-hq
# 4340961465_849a4047cc.jpg     romanian-architects-association-hq
# 3967379808_4526c9c59b.jpg                 camposanto-monumentale
# 2988311084_558330f83d.jpg                 camposanto-monumentale
# 2844827222_711aa34f1b.jpg                 camposanto-monumentale
# 6373349711_f50e22bdaf.jpg                           white-chapel
# 6967159233_e70f3f0b05.jpg        maria-magdalena-church-freiburg
# 6821038704_c1a202e644.jpg        maria-magdalena-church-freiburg
# 7354312436_b251469d3e.jpg        maria-magdalena-church-freiburg
#
#                               feature_abusir-necropolis  feature_acrylic  \
# jpg_name
# 3689713225_537b89d9b4.jpg                           0.0              0.0
# 2895586914_fe794fc4ca.jpg                           0.0              0.0
# 3690519530_e1b73f4f55.jpg                           0.0              0.0
# 4368203413_92c3399cda_z.jpg                         0.0              0.0
# 3625883327_c23d151149_z.jpg                         0.0              0.0
# 16626841870_66ef40bbb4_b.jpg                        0.0              0.0
# 4385858902_d6e9e7c654.jpg                           0.0              0.0
# 4981284997_04d7c38fea.jpg                           0.0              0.0
# 4981285055_3e4a18f8c7.jpg                           0.0              0.0
# 1418888097_715cf79a6b.jpg                           0.0              0.0
# 5512901641_e3ce133848.jpg                           0.0              0.0
# 378526474_e96daf44a3.jpg                            0.0              0.0
# 5027110955_5f6df0b54d.jpg                           0.0              0.0
# 5027115885_2c3e3d0d63.jpg                           0.0              0.0
# 3558094115_ef492ef884.jpg                           0.0              0.0
# 3853535763_a871815d68.jpg                           0.0              0.0
# 3191802718_0b625b5473.jpg                           0.0              0.0
# 3853534467_1c8b56a304.jpg                           0.0              0.0
# 6779125019_c560ea8d2c.jpg                           0.0              0.0
# 1404753880_f1b9b6046c.jpg                           0.0              0.0
# 5751067125_fe1f154b09.jpg                           0.0              0.0
# 66919505_39e17583d6.jpg                             0.0              0.0
# 4465317510_3255b4539c.jpg                           0.0              0.0
# 5030418712_44fd2dce38.jpg                           0.0              0.0
# 3364699979_4f16359b70.jpg                           0.0              0.0
# 6584963027_ef55825ecf_b.jpg                         0.0              0.0
# 8209621242_70b6931e71_b.jpg                         0.0              0.0
# 5425674028_cdff31c27f_b.jpg                         0.0              0.0
# 6014739523_ecef84bee5.jpg                           0.0              0.0
# 6015248296_b7e893e74e.jpg                           0.0              0.0
# ...                                                 ...              ...
# 2521458754_463b5e3f29.jpg                           0.0              0.0
# 3968504263_e03b5b162c.jpg                           0.0              0.0
# 4903978088_5c69e05130.jpg                           0.0              0.0
# 4903389675_d44822b49c.jpg                           0.0              0.0
# 2373204758_fb40abda43_o.jpg                         0.0              0.0
# 2620391981_0ba61118f6_z.jpg                         0.0              0.0
# 3321920891_57f5359ea7_b.jpg                         0.0              0.0
# 5210350350_223a960a20.jpg                           0.0              0.0
# 5209755927_eeab13f204.jpg                           0.0              0.0
# 5210305092_fa300b7895.jpg                           0.0              0.0
# 8669942886_e328513a71_b.jpg                         0.0              0.0
# 2528949652_d431f64e0c.jpg                           0.0              0.0
# 3389649775_c2c6682018.jpg                           0.0              0.0
# 2823335798_afb43b8dbc.jpg                           0.0              0.0
# 3482362202_deeb923920_b.jpg                         0.0              0.0
# 6814677809_a500c1168e_b.jpg                         0.0              0.0
# 4533888124_347b9b2953_b.jpg                         0.0              0.0
# 5950681881_b90166cb44.jpg                           0.0              0.0
# 25380616_00614f85d4.jpg                             0.0              0.0
# 3461463230_bd8bc03914.jpg                           0.0              0.0
# 4152967191_d3a647e9d0.jpg                           0.0              0.0
# 5367755404_46d3222e5f.jpg                           0.0              0.0
# 4340961465_849a4047cc.jpg                           0.0              0.0
# 3967379808_4526c9c59b.jpg                           0.0              0.0
# 2988311084_558330f83d.jpg                           0.0              0.0
# 2844827222_711aa34f1b.jpg                           0.0              0.0
# 6373349711_f50e22bdaf.jpg                           0.0              0.0
# 6967159233_e70f3f0b05.jpg                           0.0              0.0
# 6821038704_c1a202e644.jpg                           0.0              0.0
# 7354312436_b251469d3e.jpg                           0.0              0.0
#
#                               feature_addition        ...          \
# jpg_name                                              ...
# 3689713225_537b89d9b4.jpg                  0.0        ...
# 2895586914_fe794fc4ca.jpg                  0.0        ...
# 3690519530_e1b73f4f55.jpg                  0.0        ...
# 4368203413_92c3399cda_z.jpg                0.0        ...
# 3625883327_c23d151149_z.jpg                0.0        ...
# 16626841870_66ef40bbb4_b.jpg               0.0        ...
# 4385858902_d6e9e7c654.jpg                  0.0        ...
# 4981284997_04d7c38fea.jpg                  0.0        ...
# 4981285055_3e4a18f8c7.jpg                  0.0        ...
# 1418888097_715cf79a6b.jpg                  0.0        ...
# 5512901641_e3ce133848.jpg                  0.0        ...
# 378526474_e96daf44a3.jpg                   0.0        ...
# 5027110955_5f6df0b54d.jpg                  0.0        ...
# 5027115885_2c3e3d0d63.jpg                  0.0        ...
# 3558094115_ef492ef884.jpg                  0.0        ...
# 3853535763_a871815d68.jpg                  0.0        ...
# 3191802718_0b625b5473.jpg                  0.0        ...
# 3853534467_1c8b56a304.jpg                  0.0        ...
# 6779125019_c560ea8d2c.jpg                  0.0        ...
# 1404753880_f1b9b6046c.jpg                  0.0        ...
# 5751067125_fe1f154b09.jpg                  0.0        ...
# 66919505_39e17583d6.jpg                    0.0        ...
# 4465317510_3255b4539c.jpg                  0.0        ...
# 5030418712_44fd2dce38.jpg                  0.0        ...
# 3364699979_4f16359b70.jpg                  0.0        ...
# 6584963027_ef55825ecf_b.jpg                0.0        ...
# 8209621242_70b6931e71_b.jpg                0.0        ...
# 5425674028_cdff31c27f_b.jpg                0.0        ...
# 6014739523_ecef84bee5.jpg                  0.0        ...
# 6015248296_b7e893e74e.jpg                  0.0        ...
# ...                                        ...        ...
# 2521458754_463b5e3f29.jpg                  0.0        ...
# 3968504263_e03b5b162c.jpg                  0.0        ...
# 4903978088_5c69e05130.jpg                  0.0        ...
# 4903389675_d44822b49c.jpg                  0.0        ...
# 2373204758_fb40abda43_o.jpg                0.0        ...
# 2620391981_0ba61118f6_z.jpg                0.0        ...
# 3321920891_57f5359ea7_b.jpg                0.0        ...
# 5210350350_223a960a20.jpg                  0.0        ...
# 5209755927_eeab13f204.jpg                  0.0        ...
# 5210305092_fa300b7895.jpg                  0.0        ...
# 8669942886_e328513a71_b.jpg                0.0        ...
# 2528949652_d431f64e0c.jpg                  0.0        ...
# 3389649775_c2c6682018.jpg                  0.0        ...
# 2823335798_afb43b8dbc.jpg                  0.0        ...
# 3482362202_deeb923920_b.jpg                0.0        ...
# 6814677809_a500c1168e_b.jpg                0.0        ...
# 4533888124_347b9b2953_b.jpg                0.0        ...
# 5950681881_b90166cb44.jpg                  0.0        ...
# 25380616_00614f85d4.jpg                    0.0        ...
# 3461463230_bd8bc03914.jpg                  0.0        ...
# 4152967191_d3a647e9d0.jpg                  1.0        ...
# 5367755404_46d3222e5f.jpg                  1.0        ...
# 4340961465_849a4047cc.jpg                  1.0        ...
# 3967379808_4526c9c59b.jpg                  0.0        ...
# 2988311084_558330f83d.jpg                  0.0        ...
# 2844827222_711aa34f1b.jpg                  0.0        ...
# 6373349711_f50e22bdaf.jpg                  0.0        ...
# 6967159233_e70f3f0b05.jpg                  0.0        ...
# 6821038704_c1a202e644.jpg                  0.0        ...
# 7354312436_b251469d3e.jpg                  0.0        ...
#
#                               feature_zeche-zollverein  feature_zero-energy  \
# jpg_name
# 3689713225_537b89d9b4.jpg                          0.0                  0.0
# 2895586914_fe794fc4ca.jpg                          0.0                  0.0
# 3690519530_e1b73f4f55.jpg                          0.0                  0.0
# 4368203413_92c3399cda_z.jpg                        0.0                  0.0
# 3625883327_c23d151149_z.jpg                        0.0                  0.0
# 16626841870_66ef40bbb4_b.jpg                       0.0                  0.0
# 4385858902_d6e9e7c654.jpg                          0.0                  0.0
# 4981284997_04d7c38fea.jpg                          0.0                  0.0
# 4981285055_3e4a18f8c7.jpg                          0.0                  0.0
# 1418888097_715cf79a6b.jpg                          0.0                  0.0
# 5512901641_e3ce133848.jpg                          0.0                  0.0
# 378526474_e96daf44a3.jpg                           0.0                  0.0
# 5027110955_5f6df0b54d.jpg                          0.0                  0.0
# 5027115885_2c3e3d0d63.jpg                          0.0                  0.0
# 3558094115_ef492ef884.jpg                          0.0                  0.0
# 3853535763_a871815d68.jpg                          0.0                  0.0
# 3191802718_0b625b5473.jpg                          0.0                  0.0
# 3853534467_1c8b56a304.jpg                          0.0                  0.0
# 6779125019_c560ea8d2c.jpg                          0.0                  0.0
# 1404753880_f1b9b6046c.jpg                          0.0                  0.0
# 5751067125_fe1f154b09.jpg                          0.0                  0.0
# 66919505_39e17583d6.jpg                            0.0                  0.0
# 4465317510_3255b4539c.jpg                          0.0                  0.0
# 5030418712_44fd2dce38.jpg                          0.0                  0.0
# 3364699979_4f16359b70.jpg                          0.0                  0.0
# 6584963027_ef55825ecf_b.jpg                        0.0                  0.0
# 8209621242_70b6931e71_b.jpg                        0.0                  0.0
# 5425674028_cdff31c27f_b.jpg                        0.0                  0.0
# 6014739523_ecef84bee5.jpg                          0.0                  0.0
# 6015248296_b7e893e74e.jpg                          0.0                  0.0
# ...                                                ...                  ...
# 2521458754_463b5e3f29.jpg                          0.0                  0.0
# 3968504263_e03b5b162c.jpg                          0.0                  0.0
# 4903978088_5c69e05130.jpg                          0.0                  0.0
# 4903389675_d44822b49c.jpg                          0.0                  0.0
# 2373204758_fb40abda43_o.jpg                        0.0                  0.0
# 2620391981_0ba61118f6_z.jpg                        0.0                  0.0
# 3321920891_57f5359ea7_b.jpg                        0.0                  0.0
# 5210350350_223a960a20.jpg                          0.0                  0.0
# 5209755927_eeab13f204.jpg                          0.0                  0.0
# 5210305092_fa300b7895.jpg                          0.0                  0.0
# 8669942886_e328513a71_b.jpg                        0.0                  0.0
# 2528949652_d431f64e0c.jpg                          0.0                  0.0
# 3389649775_c2c6682018.jpg                          0.0                  0.0
# 2823335798_afb43b8dbc.jpg                          0.0                  0.0
# 3482362202_deeb923920_b.jpg                        0.0                  0.0
# 6814677809_a500c1168e_b.jpg                        0.0                  0.0
# 4533888124_347b9b2953_b.jpg                        0.0                  0.0
# 5950681881_b90166cb44.jpg                          0.0                  0.0
# 25380616_00614f85d4.jpg                            0.0                  0.0
# 3461463230_bd8bc03914.jpg                          0.0                  0.0
# 4152967191_d3a647e9d0.jpg                          0.0                  0.0
# 5367755404_46d3222e5f.jpg                          0.0                  0.0
# 4340961465_849a4047cc.jpg                          0.0                  0.0
# 3967379808_4526c9c59b.jpg                          0.0                  0.0
# 2988311084_558330f83d.jpg                          0.0                  0.0
# 2844827222_711aa34f1b.jpg                          0.0                  0.0
# 6373349711_f50e22bdaf.jpg                          0.0                  0.0
# 6967159233_e70f3f0b05.jpg                          0.0                  0.0
# 6821038704_c1a202e644.jpg                          0.0                  0.0
# 7354312436_b251469d3e.jpg                          0.0                  0.0
#
#                               feature_zig-zag  feature_ziggurat  feature_zinc  \
# jpg_name
# 3689713225_537b89d9b4.jpg                 0.0               0.0           0.0
# 2895586914_fe794fc4ca.jpg                 0.0               0.0           0.0
# 3690519530_e1b73f4f55.jpg                 0.0               0.0           0.0
# 4368203413_92c3399cda_z.jpg               0.0               0.0           0.0
# 3625883327_c23d151149_z.jpg               0.0               0.0           0.0
# 16626841870_66ef40bbb4_b.jpg              0.0               0.0           0.0
# 4385858902_d6e9e7c654.jpg                 0.0               0.0           0.0
# 4981284997_04d7c38fea.jpg                 0.0               0.0           0.0
# 4981285055_3e4a18f8c7.jpg                 0.0               0.0           0.0
# 1418888097_715cf79a6b.jpg                 0.0               0.0           0.0
# 5512901641_e3ce133848.jpg                 0.0               0.0           0.0
# 378526474_e96daf44a3.jpg                  0.0               0.0           0.0
# 5027110955_5f6df0b54d.jpg                 0.0               0.0           0.0
# 5027115885_2c3e3d0d63.jpg                 0.0               0.0           0.0
# 3558094115_ef492ef884.jpg                 0.0               0.0           0.0
# 3853535763_a871815d68.jpg                 0.0               0.0           0.0
# 3191802718_0b625b5473.jpg                 0.0               0.0           0.0
# 3853534467_1c8b56a304.jpg                 0.0               0.0           0.0
# 6779125019_c560ea8d2c.jpg                 1.0               0.0           0.0
# 1404753880_f1b9b6046c.jpg                 1.0               0.0           0.0
# 5751067125_fe1f154b09.jpg                 1.0               0.0           0.0
# 66919505_39e17583d6.jpg                   0.0               0.0           0.0
# 4465317510_3255b4539c.jpg                 0.0               0.0           0.0
# 5030418712_44fd2dce38.jpg                 0.0               0.0           0.0
# 3364699979_4f16359b70.jpg                 0.0               0.0           0.0
# 6584963027_ef55825ecf_b.jpg               0.0               0.0           0.0
# 8209621242_70b6931e71_b.jpg               0.0               0.0           0.0
# 5425674028_cdff31c27f_b.jpg               0.0               0.0           0.0
# 6014739523_ecef84bee5.jpg                 0.0               0.0           0.0
# 6015248296_b7e893e74e.jpg                 0.0               0.0           0.0
# ...                                       ...               ...           ...
# 2521458754_463b5e3f29.jpg                 0.0               0.0           0.0
# 3968504263_e03b5b162c.jpg                 0.0               0.0           0.0
# 4903978088_5c69e05130.jpg                 0.0               0.0           0.0
# 4903389675_d44822b49c.jpg                 0.0               0.0           0.0
# 2373204758_fb40abda43_o.jpg               0.0               0.0           0.0
# 2620391981_0ba61118f6_z.jpg               0.0               0.0           0.0
# 3321920891_57f5359ea7_b.jpg               0.0               0.0           0.0
# 5210350350_223a960a20.jpg                 0.0               0.0           0.0
# 5209755927_eeab13f204.jpg                 0.0               0.0           0.0
# 5210305092_fa300b7895.jpg                 0.0               0.0           0.0
# 8669942886_e328513a71_b.jpg               0.0               0.0           0.0
# 2528949652_d431f64e0c.jpg                 0.0               0.0           0.0
# 3389649775_c2c6682018.jpg                 0.0               0.0           0.0
# 2823335798_afb43b8dbc.jpg                 0.0               0.0           0.0
# 3482362202_deeb923920_b.jpg               0.0               0.0           0.0
# 6814677809_a500c1168e_b.jpg               0.0               0.0           0.0
# 4533888124_347b9b2953_b.jpg               0.0               0.0           0.0
# 5950681881_b90166cb44.jpg                 0.0               0.0           0.0
# 25380616_00614f85d4.jpg                   0.0               0.0           0.0
# 3461463230_bd8bc03914.jpg                 0.0               0.0           0.0
# 4152967191_d3a647e9d0.jpg                 0.0               0.0           0.0
# 5367755404_46d3222e5f.jpg                 0.0               0.0           0.0
# 4340961465_849a4047cc.jpg                 0.0               0.0           0.0
# 3967379808_4526c9c59b.jpg                 0.0               0.0           0.0
# 2988311084_558330f83d.jpg                 0.0               0.0           0.0
# 2844827222_711aa34f1b.jpg                 0.0               0.0           0.0
# 6373349711_f50e22bdaf.jpg                 0.0               0.0           0.0
# 6967159233_e70f3f0b05.jpg                 1.0               0.0           0.0
# 6821038704_c1a202e644.jpg                 1.0               0.0           0.0
# 7354312436_b251469d3e.jpg                 1.0               0.0           0.0
#
#                               feature_Oya-stone  building_main_style  \
# jpg_name
# 3689713225_537b89d9b4.jpg                   0.0           vernacular
# 2895586914_fe794fc4ca.jpg                   0.0           vernacular
# 3690519530_e1b73f4f55.jpg                   0.0           vernacular
# 4368203413_92c3399cda_z.jpg                 0.0         neoclassical
# 3625883327_c23d151149_z.jpg                 0.0         neoclassical
# 16626841870_66ef40bbb4_b.jpg                0.0         neoclassical
# 4385858902_d6e9e7c654.jpg                   0.0               modern
# 4981284997_04d7c38fea.jpg                   0.0               modern
# 4981285055_3e4a18f8c7.jpg                   0.0               modern
# 1418888097_715cf79a6b.jpg                   0.0        ancient-roman
# 5512901641_e3ce133848.jpg                   0.0        ancient-roman
# 378526474_e96daf44a3.jpg                    0.0        ancient-roman
# 5027110955_5f6df0b54d.jpg                   0.0               modern
# 5027115885_2c3e3d0d63.jpg                   0.0               modern
# 3558094115_ef492ef884.jpg                   0.0               modern
# 3853535763_a871815d68.jpg                   0.0      neo-renaissance
# 3191802718_0b625b5473.jpg                   0.0      neo-renaissance
# 3853534467_1c8b56a304.jpg                   0.0      neo-renaissance
# 6779125019_c560ea8d2c.jpg                   0.0               modern
# 1404753880_f1b9b6046c.jpg                   0.0               modern
# 5751067125_fe1f154b09.jpg                   0.0               modern
# 66919505_39e17583d6.jpg                     0.0          post-modern
# 4465317510_3255b4539c.jpg                   0.0          post-modern
# 5030418712_44fd2dce38.jpg                   0.0               norman
# 3364699979_4f16359b70.jpg                   0.0               norman
# 6584963027_ef55825ecf_b.jpg                 0.0    neo-mediterranean
# 8209621242_70b6931e71_b.jpg                 0.0    neo-mediterranean
# 5425674028_cdff31c27f_b.jpg                 0.0    neo-mediterranean
# 6014739523_ecef84bee5.jpg                   0.0               modern
# 6015248296_b7e893e74e.jpg                   0.0               modern
# ...                                         ...                  ...
# 2521458754_463b5e3f29.jpg                   0.0               modern
# 3968504263_e03b5b162c.jpg                   0.0             medieval
# 4903978088_5c69e05130.jpg                   0.0             medieval
# 4903389675_d44822b49c.jpg                   0.0             medieval
# 2373204758_fb40abda43_o.jpg                 0.0               modern
# 2620391981_0ba61118f6_z.jpg                 0.0               modern
# 3321920891_57f5359ea7_b.jpg                 0.0               modern
# 5210350350_223a960a20.jpg                   0.0             japanese
# 5209755927_eeab13f204.jpg                   0.0             japanese
# 5210305092_fa300b7895.jpg                   0.0             japanese
# 8669942886_e328513a71_b.jpg                 0.0               modern
# 2528949652_d431f64e0c.jpg                   0.0               modern
# 3389649775_c2c6682018.jpg                   0.0               modern
# 2823335798_afb43b8dbc.jpg                   0.0               modern
# 3482362202_deeb923920_b.jpg                 0.0               modern
# 6814677809_a500c1168e_b.jpg                 0.0               modern
# 4533888124_347b9b2953_b.jpg                 0.0               modern
# 5950681881_b90166cb44.jpg                   0.0        ancient-aztec
# 25380616_00614f85d4.jpg                     0.0        ancient-aztec
# 3461463230_bd8bc03914.jpg                   0.0        ancient-aztec
# 4152967191_d3a647e9d0.jpg                   0.0               modern
# 5367755404_46d3222e5f.jpg                   0.0               modern
# 4340961465_849a4047cc.jpg                   0.0               modern
# 3967379808_4526c9c59b.jpg                   0.0               gothic
# 2988311084_558330f83d.jpg                   0.0               gothic
# 2844827222_711aa34f1b.jpg                   0.0               gothic
# 6373349711_f50e22bdaf.jpg                   0.0               modern
# 6967159233_e70f3f0b05.jpg                   0.0               modern
# 6821038704_c1a202e644.jpg                   0.0               modern
# 7354312436_b251469d3e.jpg                   0.0               modern
#
#                               building_sub_style  building_main_type  \
# jpg_name
# 3689713225_537b89d9b4.jpg                italian           religious
# 2895586914_fe794fc4ca.jpg                italian           religious
# 3690519530_e1b73f4f55.jpg                italian           religious
# 4368203413_92c3399cda_z.jpg                 None              public
# 3625883327_c23d151149_z.jpg                 None              public
# 16626841870_66ef40bbb4_b.jpg                None              public
# 4385858902_d6e9e7c654.jpg               futurist         residential
# 4981284997_04d7c38fea.jpg               futurist         residential
# 4981285055_3e4a18f8c7.jpg               futurist         residential
# 1418888097_715cf79a6b.jpg                   None           religious
# 5512901641_e3ce133848.jpg                   None           religious
# 378526474_e96daf44a3.jpg                    None           religious
# 5027110955_5f6df0b54d.jpg                   None              public
# 5027115885_2c3e3d0d63.jpg                   None              public
# 3558094115_ef492ef884.jpg                   None              public
# 3853535763_a871815d68.jpg                   None           religious
# 3191802718_0b625b5473.jpg                   None           religious
# 3853534467_1c8b56a304.jpg                   None           religious
# 6779125019_c560ea8d2c.jpg                   None               tower
# 1404753880_f1b9b6046c.jpg                   None               tower
# 5751067125_fe1f154b09.jpg                   None               tower
# 66919505_39e17583d6.jpg                     None               tower
# 4465317510_3255b4539c.jpg                   None               tower
# 5030418712_44fd2dce38.jpg                   None           religious
# 3364699979_4f16359b70.jpg                   None           religious
# 6584963027_ef55825ecf_b.jpg                 None               civic
# 8209621242_70b6931e71_b.jpg                 None               civic
# 5425674028_cdff31c27f_b.jpg                 None               civic
# 6014739523_ecef84bee5.jpg             structural            assembly
# 6015248296_b7e893e74e.jpg             structural            assembly
# ...                                          ...                 ...
# 2521458754_463b5e3f29.jpg                   None          commercial
# 3968504263_e03b5b162c.jpg                   None           defensive
# 4903978088_5c69e05130.jpg                   None           defensive
# 4903389675_d44822b49c.jpg                   None           defensive
# 2373204758_fb40abda43_o.jpg           structural              public
# 2620391981_0ba61118f6_z.jpg           structural              public
# 3321920891_57f5359ea7_b.jpg           structural              public
# 5210350350_223a960a20.jpg                   None           religious
# 5209755927_eeab13f204.jpg                   None           religious
# 5210305092_fa300b7895.jpg                   None           religious
# 8669942886_e328513a71_b.jpg                 None         residential
# 2528949652_d431f64e0c.jpg                   None               tower
# 3389649775_c2c6682018.jpg                   None               tower
# 2823335798_afb43b8dbc.jpg                   None               tower
# 3482362202_deeb923920_b.jpg          mid-century              public
# 6814677809_a500c1168e_b.jpg          mid-century              public
# 4533888124_347b9b2953_b.jpg          mid-century              public
# 5950681881_b90166cb44.jpg                   None           religious
# 25380616_00614f85d4.jpg                     None           religious
# 3461463230_bd8bc03914.jpg                   None           religious
# 4152967191_d3a647e9d0.jpg                   None          commercial
# 5367755404_46d3222e5f.jpg                   None          commercial
# 4340961465_849a4047cc.jpg                   None          commercial
# 3967379808_4526c9c59b.jpg                italian           religious
# 2988311084_558330f83d.jpg                italian           religious
# 2844827222_711aa34f1b.jpg                italian           religious
# 6373349711_f50e22bdaf.jpg                   None           religious
# 6967159233_e70f3f0b05.jpg                   mass           religious
# 6821038704_c1a202e644.jpg                   mass           religious
# 7354312436_b251469d3e.jpg                   mass           religious
#
#                               building_sub_type
# jpg_name
# 3689713225_537b89d9b4.jpg              monument
# 2895586914_fe794fc4ca.jpg              monument
# 3690519530_e1b73f4f55.jpg              monument
# 4368203413_92c3399cda_z.jpg              museum
# 3625883327_c23d151149_z.jpg              museum
# 16626841870_66ef40bbb4_b.jpg             museum
# 4385858902_d6e9e7c654.jpg         single-family
# 4981284997_04d7c38fea.jpg         single-family
# 4981285055_3e4a18f8c7.jpg         single-family
# 1418888097_715cf79a6b.jpg                temple
# 5512901641_e3ce133848.jpg                temple
# 378526474_e96daf44a3.jpg                 temple
# 5027110955_5f6df0b54d.jpg          recreational
# 5027115885_2c3e3d0d63.jpg          recreational
# 3558094115_ef492ef884.jpg          recreational
# 3853535763_a871815d68.jpg             cathedral
# 3191802718_0b625b5473.jpg             cathedral
# 3853534467_1c8b56a304.jpg             cathedral
# 6779125019_c560ea8d2c.jpg             mixed-use
# 1404753880_f1b9b6046c.jpg             mixed-use
# 5751067125_fe1f154b09.jpg             mixed-use
# 66919505_39e17583d6.jpg                  office
# 4465317510_3255b4539c.jpg                office
# 5030418712_44fd2dce38.jpg                church
# 3364699979_4f16359b70.jpg                church
# 6584963027_ef55825ecf_b.jpg           city-hall
# 8209621242_70b6931e71_b.jpg           city-hall
# 5425674028_cdff31c27f_b.jpg           city-hall
# 6014739523_ecef84bee5.jpg               stadium
# 6015248296_b7e893e74e.jpg               stadium
# ...                                         ...
# 2521458754_463b5e3f29.jpg                office
# 3968504263_e03b5b162c.jpg                castle
# 4903978088_5c69e05130.jpg                castle
# 4903389675_d44822b49c.jpg                castle
# 2373204758_fb40abda43_o.jpg              museum
# 2620391981_0ba61118f6_z.jpg              museum
# 3321920891_57f5359ea7_b.jpg              museum
# 5210350350_223a960a20.jpg                temple
# 5209755927_eeab13f204.jpg                temple
# 5210305092_fa300b7895.jpg                temple
# 8669942886_e328513a71_b.jpg        multi-family
# 2528949652_d431f64e0c.jpg                office
# 3389649775_c2c6682018.jpg                office
# 2823335798_afb43b8dbc.jpg                office
# 3482362202_deeb923920_b.jpg            pavilion
# 6814677809_a500c1168e_b.jpg            pavilion
# 4533888124_347b9b2953_b.jpg            pavilion
# 5950681881_b90166cb44.jpg                temple
# 25380616_00614f85d4.jpg                  temple
# 3461463230_bd8bc03914.jpg                temple
# 4152967191_d3a647e9d0.jpg                office
# 5367755404_46d3222e5f.jpg                office
# 4340961465_849a4047cc.jpg                office
# 3967379808_4526c9c59b.jpg              cemetary
# 2988311084_558330f83d.jpg              cemetary
# 2844827222_711aa34f1b.jpg              cemetary
# 6373349711_f50e22bdaf.jpg                chapel
# 6967159233_e70f3f0b05.jpg                church
# 6821038704_c1a202e644.jpg                church
# 7354312436_b251469d3e.jpg                church
#
# [19383 rows x 593 columns]

# %%
architecture_csv.to_csv('architecture.csv')
